# %% [markdown]
# <a href="https://colab.research.google.com/github/Andbwol/backend_test_homework/blob/master/Bond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import io

# %%
s=requests.get('https://iss.moex.com/iss/apps/infogrid/emission/rates.csv?iss.dp=comma&iss.df=%25d.%25m.%25Y&iss.tf=%25H:%25M:%25S&iss.dtf=%25d.%25m.%25Y%25H:%25M:%25S&iss.only=rates&limit=unlimited&lang=ru').content

# %%
df=pd.read_csv(io.StringIO(s.decode('cp1251')), sep=';',header=1)

# %%
df.shape
# Out:
# (2552, 55)

# %%
df.head()
# Out:
#           SECID   SHORTNAME                            NAME  \
# 0  AMUNIBB2DER6  UBANK02/24        UNIBANK OJSC Series 1 21
# 1  AT0000A2UF10  Raiff BIAG          Raiffeisen Bank Int AG
# 2  CH0248531110  VTB-24 CHF         VTB CAPITAL S.A. 24 CHF
# 3  CH0379268748  RZD-23 CHF          RZD Capital PLC 23 CHF
# 4  CH0419041618  RZD-25 CHF  RZD CAPITAL PLC 0.898 03/10/25
#
#                       TYPENAME          ISIN REGNUMBER  LISTLEVEL FACEVALUE  \
# 0  Корпоративные еврооблигации  AMUNIBB2DER6       NaN        3.0     100,0
# 1  Корпоративные еврооблигации  AT0000A2UF10       NaN        3.0    1000,0
# 2  Корпоративные еврооблигации  CH0248531110       NaN        NaN    5000,0
# 3  Корпоративные еврооблигации  CH0379268748       NaN        NaN    5000,0
# 4  Корпоративные еврооблигации  CH0419041618       NaN        NaN    5000,0
#
#   FACEUNIT  ISSUESIZE  ...  RTL3       RTH3 DISCOUNT1 LIMIT1 DISCOUNT2 LIMIT2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SECID                   2552 non-null   object
#  1   SHORTNAME               2552 non-null   object
#  2   NAME                    2552 non-null   object
#  3   TYPENAME                2552 non-null   object
#  4   ISIN                    2552 non-null   object
#  5   REGNUMBER               2237 non-null   object
#  6   LISTLEVEL               2366 non-null   float64
#  7   FACEVALUE               2552 non-null   object
#  8   FACEUNIT                2552 non-null   object
#  9   ISSUESIZE               2475 non-null   float64
#  10  IS_COLLATERAL           2552 non-null   int64
#  11  IS_EXTERNAL             2552 non-null   int64
#  12  PRIMARY_BOARDID         2552 non-null   object
#  13  PRIMARY_BOARD_TITLE     2552 non-null   object
# ...

# %%
df1 = df[['SECID', 'SHORTNAME', 'NAME', 'FACEVALUE', 'FACEUNIT','IS_QUALIFIED_INVESTORS','HIGH_RISK','COUPONFREQUENCY','COUPONDATE', 'COUPONPERCENT', 'COUPONVALUE', 'OFFERDATE', 'EMITENTNAME', 'INN', 'PRICE', 'PRICE_RUB']]

# %%
df1.head()
# Out:
#           SECID   SHORTNAME                            NAME FACEVALUE  \
# 0  AMUNIBB2DER6  UBANK02/24        UNIBANK OJSC Series 1 21     100,0
# 1  AT0000A2UF10  Raiff BIAG          Raiffeisen Bank Int AG    1000,0
# 2  CH0248531110  VTB-24 CHF         VTB CAPITAL S.A. 24 CHF    5000,0
# 3  CH0379268748  RZD-23 CHF          RZD Capital PLC 23 CHF    5000,0
# 4  CH0419041618  RZD-25 CHF  RZD CAPITAL PLC 0.898 03/10/25    5000,0
#
#   FACEUNIT  IS_QUALIFIED_INVESTORS  HIGH_RISK  COUPONFREQUENCY  COUPONDATE  \
# 0      USD                       0          0              4.0  05.08.2023
# 1      USD                       1          0              4.0  20.06.2023
# 2      CHF                       1          0              1.0  24.10.2023
# 3      CHF                       1          0              1.0  02.10.2023
# 4      CHF                       1          0              1.0  03.10.2023
#
#   COUPONPERCENT COUPONVALUE OFFERDATE                           EMITENTNAME  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SECID                   2552 non-null   object
#  1   SHORTNAME               2552 non-null   object
#  2   NAME                    2552 non-null   object
#  3   FACEVALUE               2552 non-null   object
#  4   FACEUNIT                2552 non-null   object
#  5   IS_QUALIFIED_INVESTORS  2552 non-null   int64
#  6   HIGH_RISK               2552 non-null   int64
#  7   COUPONFREQUENCY         2141 non-null   float64
#  8   COUPONDATE              2541 non-null   object
#  9   COUPONPERCENT           2345 non-null   object
#  10  COUPONVALUE             2346 non-null   object
#  11  OFFERDATE               367 non-null    object
#  12  EMITENTNAME             2552 non-null   object
#  13  INN                     2547 non-null   float64
# ...

# %%
df1.groupby('FACEUNIT').count()
# Out:
#           SECID  SHORTNAME  NAME  FACEVALUE  IS_QUALIFIED_INVESTORS  \
# FACEUNIT
# CHF           7          7     7          7                       7
# CNY          28         28    28         28                      28
# EUR          39         39    39         39                      39
# GBP           3          3     3          3                       3
# RUB        2193       2193  2193       2193                    2193
# USD         282        282   282        282                     282
#
#           HIGH_RISK  COUPONFREQUENCY  COUPONDATE  COUPONPERCENT  COUPONVALUE  \
# FACEUNIT
# CHF               7                7           7              6            7
# CNY              28               22          28             28           28
# EUR              39               37          39             32           33
# GBP               3                3           3              3            3
# RUB            2193             1802        2187           2059         2059
# ...

# %%
df1=df1[(df1.FACEUNIT=='RUB')]

# %%
df1.groupby('COUPONPERCENT').count()
# Out:
#                SECID  SHORTNAME  NAME  FACEVALUE  FACEUNIT  \
# COUPONPERCENT
# 0,010            525        525   525        525       525
# 0,016              1          1     1          1         1
# 0,020              2          2     2          2         2
# 0,030              1          1     1          1         1
# 0,040              1          1     1          1         1
# ...              ...        ...   ...        ...       ...
# 9,840              3          3     3          3         3
# 9,850              7          7     7          7         7
# 9,900             12         12    12         12        12
# 9,920              1          1     1          1         1
# 9,950              6          6     6          6         6
#
#                IS_QUALIFIED_INVESTORS  HIGH_RISK  COUPONFREQUENCY  COUPONDATE  \
# COUPONPERCENT
# 0,010                             525        525              248         525
# ...

# %%
df1 = df1.dropna(subset=['COUPONPERCENT','PRICE'])

# %%
df1.isna().sum()
# Out:
# SECID                        0
# SHORTNAME                    0
# NAME                         0
# FACEVALUE                    0
# FACEUNIT                     0
# IS_QUALIFIED_INVESTORS       0
# HIGH_RISK                    0
# COUPONFREQUENCY            332
# COUPONDATE                   0
# COUPONPERCENT                0
# COUPONVALUE                  3
# OFFERDATE                 1697
# EMITENTNAME                  0
# INN                          0
# PRICE                        0
# PRICE_RUB                    0
# dtype: int64

# %%
df1
# Out:
#              SECID   SHORTNAME                          NAME FACEVALUE  \
# 8     RU000A0JQ5C5      НПФ 01          "НПФ" ООО об.сер. 01    1000,0
# 9     RU000A0JQ7Z2  РЖД-19 обл   "Российские ЖД" ОАО 19 обл.    1000,0
# 10    RU000A0JQAM6  ДОМ.РФ15об     ДОМ.РФ (АО) обл. сер. А15    1000,0
# 11    RU000A0JQRD9  РЖД-23 обл   "Российские ЖД" ОАО 23 обл.    1000,0
# 12    RU000A0JR4U9  ГлДорога 3  Главная дорога АО об.сер. 03     750,0
# ...            ...         ...                           ...       ...
# 2511  XS2368111584  ALFA-25 RU   Alfa Bond Issuance 04/08/25  100000,0
# 2523  XS2388458403  BCS12/26-2         BCS SP Plc Series 215  100000,0
# 2540  XS2415466676  BCS11/24-8         BCS SP Plc Series 229  100000,0
# 2543  XS2417535650  BCS06/25-A         BCS SP Plc Series 234  100000,0
# 2547  XS2420560869    BCS01/25         BCS SP Plc Series 239  100000,0
#
#      FACEUNIT  IS_QUALIFIED_INVESTORS  HIGH_RISK  COUPONFREQUENCY  COUPONDATE  \
# ...

# %%
df.sort_values('COUPONPERCENT')
# Out:
# Empty DataFrame
# Columns: [SECID, SHORTNAME, NAME, TYPENAME, ISIN, REGNUMBER, LISTLEVEL, FACEVALUE, FACEUNIT, ISSUESIZE, IS_COLLATERAL, IS_EXTERNAL, PRIMARY_BOARDID, PRIMARY_BOARD_TITLE, MATDATE, IS_RII, EVENINGSESSION, MORNINGSESSION, INCLUDEDBYMOEX, DURATION, IS_QUALIFIED_INVESTORS, HIGH_RISK, COUPONFREQUENCY, YIELDATWAP, COUPONDATE, COUPONPERCENT, COUPONVALUE, COUPONDAYSPASSED, COUPONDAYSREMAIN, COUPONLENGTH, ISSUEDATE, INITIALFACEVALUE, SECSUBTYPE, STARTDATEMOEX, DAYSTOREDEMPTION, OFFERDATE, EMITENTNAME, INN, LOTSIZE, PRICE, PRICE_RUB, RTL1, RTH1, RTL2, RTH2, RTL3, RTH3, DISCOUNT1, LIMIT1, DISCOUNT2, LIMIT2, DISCOUNT3, DISCOUNTL0, DISCOUNTH0, FULLCOVERED]
# Index: []
#
# [0 rows x 55 columns]

# %%
df.sort_values('COUPONPERCENT')
# Out:
#              SECID   SHORTNAME                           NAME  \
# 1828  RU000A105161  СберИОС534   СберИОС 001Р-534R 3Г НОВАТЭК
# 2100  RU000A105XK4  АЛЬФАС1-62   АЛЬФА-Б C-1-62 (структурные)
# 1755  RU000A104KZ2  СберИОС530    СберИОС 001Р-530R 5Г SBERRM
# 1080  RU000A1028K0  СберИОС355       СберИОС 001Р-355R 5Y ТЕХ
# 1079  RU000A1028J2  СберИОС354  СберИОС 001Р-354R 5Г SBERLV85
# ...            ...         ...                            ...
# 2547  XS2420560869    BCS01/25          BCS SP Plc Series 239
# 2548  XS2423361190  BCS02/27-4          BCS SP Plc Series 240
# 2549  XS2429208486    BCS05/25          BCS SP Plc Series 243
# 2550  XS2439218640  BCS06/25-B          BCS SP Plc Series 244
# 2551  XS2446844321  BCS06/25-C          BCS SP Plc Series 245
#
#                          TYPENAME          ISIN              REGNUMBER  \
# 1828           Биржевые облигации  RU000A105161  4B02-560-01481-B-001P
# 2100      Корпоративные облигации  RU000A105XK4      6-62-01326-B-001P
# ...

# %%
df.groupby('FACEUNIT').count()
# Out:
#           SECID  SHORTNAME  NAME  TYPENAME  ISIN  REGNUMBER  LISTLEVEL  \
# FACEUNIT
# CHF           6          6     6         6     6          1          1
# CNY          28         28    28        28    28         27         22
# EUR          39         39    39        39    39         19         34
# GBP           3          3     3         3     3          1          1
# RUB        2188       2188  2188      2188  2188       2118       2089
# USD         283        283   283       283   283         66        217
#
#           FACEVALUE  ISSUESIZE  IS_COLLATERAL  ...  RTL3  RTH3  DISCOUNT1  \
# FACEUNIT                                       ...
# CHF               6          6              6  ...     6     6          6
# CNY              28         22             28  ...    28    28         28
# EUR              39         39             39  ...    37    37         39
# GBP               3          3              3  ...     3     3          3
# ...

# %%
df1=df[(df.FACEUNIT=='RUB')]

# %%
df_low=df1[(df1.HIGH_RISK==0)]

# %%
df_low2=pd.DataFrame(df_low)

# %%
df_low.set_index(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-08b4fbe0dd22> in <cell line: 1>()
# ----> 1 df_low.set_index(index)
#
# NameError: name 'index' is not defined

# %%
df_low.reset_index(drop=True, inplace=True)

# %%
df_low
# Out:
#              SECID   SHORTNAME                          NAME  \
# 0     RU000A0JQ7Z2  РЖД-19 обл   "Российские ЖД" ОАО 19 обл.
# 1     RU000A0JQAM6  ДОМ.РФ15об     ДОМ.РФ (АО) обл. сер. А15
# 2     RU000A0JQRD9  РЖД-23 обл   "Российские ЖД" ОАО 23 обл.
# 3     RU000A0JR4U9  ГлДорога 3  Главная дорога АО об.сер. 03
# 4     RU000A0JRDY3  ДОМ.РФ18об      ДОМ.РФ (АО) обл. сер.А18
# ...            ...         ...                           ...
# 2063  XS2368111584  ALFA-25 RU   Alfa Bond Issuance 04/08/25
# 2064  XS2388458403  BCS12/26-2         BCS SP Plc Series 215
# 2065  XS2415466676  BCS11/24-8         BCS SP Plc Series 229
# 2066  XS2417535650  BCS06/25-A         BCS SP Plc Series 234
# 2067  XS2420560869    BCS01/25         BCS SP Plc Series 239
#
#                          TYPENAME          ISIN     REGNUMBER  LISTLEVEL  \
# 0         Корпоративные облигации  RU000A0JQ7Z2  4-19-65045-D        2.0
# 1         Корпоративные облигации  RU000A0JQAM6  4-15-00739-A        1.0
# ...

# %%
df_low['COUPONAGE'] = df_low.COUPONDAYSPASSED / df_low.COUPONLENGTH
# Out:
# <ipython-input-97-6e5c37a0605d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_low['COUPONAGE'] = df_low.COUPONDAYSPASSED / df_low.COUPONLENGTH

# %%
df_low(df_low['COUPONAGE']>0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-f53bc3519fed> in <cell line: 1>()
# ----> 1 df_low(df_low['COUPONAGE']>0.2)
#
# TypeError: 'DataFrame' object is not callable

# %%
df_low.fillna(0)
# Out:
#              SECID   SHORTNAME                          NAME  \
# 0     RU000A0JQ7Z2  РЖД-19 обл   "Российские ЖД" ОАО 19 обл.
# 1     RU000A0JQAM6  ДОМ.РФ15об     ДОМ.РФ (АО) обл. сер. А15
# 2     RU000A0JQRD9  РЖД-23 обл   "Российские ЖД" ОАО 23 обл.
# 3     RU000A0JR4U9  ГлДорога 3  Главная дорога АО об.сер. 03
# 4     RU000A0JRDY3  ДОМ.РФ18об      ДОМ.РФ (АО) обл. сер.А18
# ...            ...         ...                           ...
# 2063  XS2368111584  ALFA-25 RU   Alfa Bond Issuance 04/08/25
# 2064  XS2388458403  BCS12/26-2         BCS SP Plc Series 215
# 2065  XS2415466676  BCS11/24-8         BCS SP Plc Series 229
# 2066  XS2417535650  BCS06/25-A         BCS SP Plc Series 234
# 2067  XS2420560869    BCS01/25         BCS SP Plc Series 239
#
#                          TYPENAME          ISIN     REGNUMBER  LISTLEVEL  \
# 0         Корпоративные облигации  RU000A0JQ7Z2  4-19-65045-D        2.0
# 1         Корпоративные облигации  RU000A0JQAM6  4-15-00739-A        1.0
# ...

# %%
df_low.insert('COUPONAGE', int('COUPONDAYSPASSED'])/int('COUPONLENGTH'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-0721272a60b3> in <cell line: 1>()
# ----> 1 df_low.insert('COUPONAGE', int(['COUPONDAYSPASSED'])/int('COUPONLENGTH'))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %% [markdown]
# df.loc[df['set_of_numbers'] <= 4, 'equal_or_lower_than_4?'] = 'True'
# df.loc[df['set_of_numbers'] > 4, 'equal_or_lower_than_4?'] = 'False'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
df_low.NKD
# Out:
# 0       2.997665
# 1       2.010870
# 2       2.782005
# 3       9.428516
# 4       0.910797
#           ...
# 2063    2.450414
# 2064    0.000000
# 2065    0.004932
# 2066         NaN
# 2067    0.000000
# Name: NKD, Length: 2068, dtype: float64

# %%
df_low=df_low.fillna(0)

# %%
df_low['COUPONPERCENT'] = df_low['COUPONPERCENT'].str.replace(',', '.').astype(float).fillna(0)

# %%
df_low['FACEVALUE'] = df_low['FACEVALUE'].str.replace(',', '.').astype(float).fillna(0)

# %%
df_low.loc[df_low['COUPONAGE']>=0.2,'NKD']= df_low.FACEVALUE*df_low.COUPONAGE*(df_low.COUPONPERCENT/df_low.COUPONFREQUENCY)

# %%
df_low.NKD
# Out:
# 0         2997.664835
# 1         2010.869565
# 2         2782.005495
# 3         7071.387363
# 4          273.239011
#             ...
# 2063    245041.436464
# 2064         0.000000
# 2065       493.150685
# 2066              NaN
# 2067         0.000000
# Name: NKD, Length: 2068, dtype: float64

# %%
df_low.loc[[2063]]
# Out:
#              SECID   SHORTNAME                         NAME  \
# 2063  XS2368111584  ALFA-25 RU  Alfa Bond Issuance 04/08/25
#
#                          TYPENAME          ISIN REGNUMBER  LISTLEVEL  \
# 2063  Корпоративные еврооблигации  XS2368111584         0        0.0
#
#       FACEVALUE FACEUNIT  ISSUESIZE  ...  DISCOUNT1  LIMIT1 DISCOUNT2  \
# 2063   100000.0      RUB   100000.0  ...       17,0  2000.0      29,0
#
#        LIMIT2 DISCOUNT3 DISCOUNTL0  DISCOUNTH0  FULLCOVERED  COUPONAGE  \
# 2063  10000.0      40,0   17,00000    17,00000          0.0   0.624309
#
#                 NKD
# 2063  245041.436464
#
# [1 rows x 56 columns]

# %%
display(df_low[(df_low['COUPONAGE']>=0.2)])
# Out:
#              SECID   SHORTNAME                          NAME  \
# 0     RU000A0JQ7Z2  РЖД-19 обл   "Российские ЖД" ОАО 19 обл.
# 1     RU000A0JQAM6  ДОМ.РФ15об     ДОМ.РФ (АО) обл. сер. А15
# 2     RU000A0JQRD9  РЖД-23 обл   "Российские ЖД" ОАО 23 обл.
# 3     RU000A0JR4U9  ГлДорога 3  Главная дорога АО об.сер. 03
# 4     RU000A0JRDY3  ДОМ.РФ18об      ДОМ.РФ (АО) обл. сер.А18
# ...            ...         ...                           ...
# 2063  XS2368111584  ALFA-25 RU   Alfa Bond Issuance 04/08/25
# 2064  XS2388458403  BCS12/26-2         BCS SP Plc Series 215
# 2065  XS2415466676  BCS11/24-8         BCS SP Plc Series 229
# 2066  XS2417535650  BCS06/25-A         BCS SP Plc Series 234
# 2067  XS2420560869    BCS01/25         BCS SP Plc Series 239
#
#                          TYPENAME          ISIN     REGNUMBER  LISTLEVEL  \
# 0         Корпоративные облигации  RU000A0JQ7Z2  4-19-65045-D        2.0
# 1         Корпоративные облигации  RU000A0JQAM6  4-15-00739-A        1.0
# ...

# %%
df_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2068 entries, 8 to 2542
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SECID                   2068 non-null   object
#  1   SHORTNAME               2068 non-null   object
#  2   NAME                    2068 non-null   object
#  3   TYPENAME                2068 non-null   object
#  4   ISIN                    2068 non-null   object
#  5   REGNUMBER               1998 non-null   object
#  6   LISTLEVEL               1969 non-null   float64
#  7   FACEVALUE               2068 non-null   object
#  8   FACEUNIT                2068 non-null   object
#  9   ISSUESIZE               2000 non-null   float64
#  10  IS_COLLATERAL           2068 non-null   int64
#  11  IS_EXTERNAL             2068 non-null   int64
#  12  PRIMARY_BOARDID         2068 non-null   object
#  13  PRIMARY_BOARD_TITLE     2068 non-null   object
# ...
